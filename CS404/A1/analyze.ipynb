# %%
import matplotlib.pyplot as plt
import numpy as np

h1_easy_cost = [83, 134, 112, 120, 96]
h1_easy_time = [0.005881786346435547, 0.07748007774353027, 0.01845407485961914, 0.006884098052978516, 0.006348848342895508]
h1_easy_searched_states = [15, 104, 20, 20, 18]
h1_easy_space = [13, 39, 15, 17, 19]

h2_easy_cost = [83, 95, 112, 90, 96]
h2_easy_time = [0.0046117305755615234, 0.1690990924835205, 0.22219586372375488, 0.01723790168762207, 0.016499757766723633]
h2_easy_searched_states = [15, 167, 244, 45, 43]
h2_easy_space = [13, 100, 67, 32, 23]

h1_medium_cost = [123, 91, 121, 105, 139]
h1_medium_time = [0.008692026138305664, 0.00814509391784668, 0.008311986923217773, 0.12026405334472656, 0.03216910362243652]
h1_medium_searched_states = [27, 26, 24, 223, 70]
h1_medium_space = [14, 17, 15, 16, 17]
74
h2_medium_cost = [74, 78, 121, 95, 105]
h2_medium_time = [0.286998987197876, 0.2340412139892578, 0.6642632484436035, 0.46450185775756836, 2.080267906188965]
h2_medium_searched_states = [282, 216, 551, 370, 660]
h2_medium_space = [75, 81, 62, 182, 219]

h1_hard_cost = [117, 136, 133, 156, 145]
h1_hard_time = [0.6339597702026367, 0.019854068756103516, 0.09542489051818848, 0.011204719543457031, 0.02209019660949707]
h1_hard_searched_states = [289, 43, 127, 31, 46]
h1_hard_space = [234, 25, 47, 22, 27]

h2_hard_cost = [106, 109, 105, 101, 118]
h2_hard_time = [23.113584756851196, 1.2099120616912842, 8.680798053741455, 6.0731611251831055, 11.485414028167725]
h2_hard_searched_states = [1679, 661, 1888, 1331, 2014]
h2_hard_space = [1199, 148, 873, 472, 553]

# %%
### bar plot for cost: easy, medium, hard in same row

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
bar_width = 0.35
index = np.arange(5)

ax[0].bar(index, h1_easy_cost, bar_width, label='h1')
ax[0].bar(index + bar_width, h2_easy_cost, bar_width, label='h2')
ax[0].set_xlabel('Instance')
ax[0].set_ylabel('Cost')
ax[0].set_title('Easy')
ax[0].set_xticks(index + bar_width / 2)
ax[0].set_xticklabels(('1', '2', '3', '4', '5'))
ax[0].legend()

ax[1].bar(index, h1_medium_cost, bar_width, label='h1')
ax[1].bar(index + bar_width, h2_medium_cost, bar_width, label='h2')
ax[1].set_xlabel('Instance')
ax[1].set_ylabel('Cost')
ax[1].set_title('Medium')
ax[1].set_xticks(index + bar_width / 2)
ax[1].set_xticklabels(('1', '2', '3', '4', '5'))
ax[1].legend()

ax[2].bar(index, h1_hard_cost, bar_width, label='h1')
ax[2].bar(index + bar_width, h2_hard_cost, bar_width, label='h2')
ax[2].set_xlabel('Instance')
ax[2].set_ylabel('Cost')
ax[2].set_title('Hard')
ax[2].set_xticks(index + bar_width / 2)
ax[2].set_xticklabels(('1', '2', '3', '4', '5'))
ax[2].legend()

plt.show()

# %%
# line plot for time: easy, medium, hard in same row

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
index = np.arange(5)

ax[0].plot(index, h1_easy_time, label='h1', linestyle='--')
ax[0].plot(index, h2_easy_time, label='h2', linestyle='--')
ax[0].set_xlabel('Instance')
ax[0].set_ylabel('Time')
ax[0].set_title('Easy')
ax[0].set_xticks(index)
ax[0].set_xticklabels(('1', '2', '3', '4', '5'))
ax[0].legend()

ax[1].plot(index, h1_medium_time, label='h1', linestyle='--')
ax[1].plot(index, h2_medium_time, label='h2', linestyle='--')
ax[1].set_xlabel('Instance')
ax[1].set_ylabel('Time')
ax[1].set_title('Medium')
ax[1].set_xticks(index)
ax[1].set_xticklabels(('1', '2', '3', '4', '5'))
ax[1].legend()

ax[2].plot(index, h1_hard_time, label='h1', linestyle='--')
ax[2].plot(index, h2_hard_time, label='h2', linestyle='--')
ax[2].set_xlabel('Instance')
ax[2].set_ylabel('Time')
ax[2].set_title('Hard')
ax[2].set_xticks(index)
ax[2].set_xticklabels(('1', '2', '3', '4', '5'))
ax[2].legend()

plt.show()

# %%
# line plot for searched states in left axis and space in right axis: easy, medium, hard in same row

fig, ax = plt.subplots(1, 3, figsize=(35, 8))

ax[0].plot(index, h1_easy_searched_states, label='h1', linestyle='--')
ax[0].plot(index, h2_easy_searched_states, label='h2', linestyle='--')
ax[0].set_xlabel('Instance')
ax[0].set_ylabel('Searched States')
ax[0].set_title('Easy')
ax[0].set_xticks(index)
ax[0].set_xticklabels(('1', '2', '3', '4', '5'))
ax[0].legend(title="Searched States", loc="upper left")

ax2 = ax[0].twinx()
ax2.plot(index, h1_easy_space, label='h1', linestyle='--', color='g')
ax2.plot(index, h2_easy_space, label='h2', linestyle='--', color='r')
ax2.set_ylabel('Space')
ax2.legend(title="Space", loc="upper right")

ax[1].plot(index, h1_medium_searched_states, label='h1', linestyle='--')
ax[1].plot(index, h2_medium_searched_states, label='h2', linestyle='--')
ax[1].set_xlabel('Instance')
ax[1].set_ylabel('Searched States')
ax[1].set_title('Medium')
ax[1].set_xticks(index)
ax[1].set_xticklabels(('1', '2', '3', '4', '5'))
ax[1].legend(title="Searched States", loc="upper left")

ax2 = ax[1].twinx()
ax2.plot(index, h1_medium_space, label='h1', linestyle='--', color='g')
ax2.plot(index, h2_medium_space, label='h2', linestyle='--', color='r')
ax2.set_ylabel('Space')
ax2.legend(title="Space", loc="upper right")

ax[2].plot(index, h1_hard_searched_states, label='h1', linestyle='--')
ax[2].plot(index, h2_hard_searched_states, label='h2', linestyle='--')
ax[2].set_xlabel('Instance')
ax[2].set_ylabel('Searched States')
ax[2].set_title('Hard')
ax[2].set_xticks(index)
ax[2].set_xticklabels(('1', '2', '3', '4', '5'))
ax[2].legend(title="Searched States", loc="upper left")

ax2 = ax[2].twinx()
ax2.plot(index, h1_hard_space, label='h1', linestyle='--', color='g')
ax2.plot(index, h2_hard_space, label='h2', linestyle='--', color='r')
ax2.set_ylabel('Space')
ax2.legend(title="Space", loc="upper right")

plt.show()
